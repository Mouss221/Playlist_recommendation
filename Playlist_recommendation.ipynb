# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder

# %%
alpha_2016 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_alpha\user_alpha_2016.csv")
alpha_2017 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_alpha\user_alpha_2017.csv")
alpha_2018 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_alpha\user_alpha_2018.csv")
alpha_2019 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_alpha\user_alpha_2019.csv")
alpha_2020 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_alpha\user_alpha_2020.csv")
alpha_2021 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_alpha\user_alpha_2021.csv")
alpha_2022 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_alpha\user_alpha_2022.csv")

# %%
beta_2016 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_beta\user_beta_2016.csv")
beta_2017 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_beta\user_beta_2017.csv")
beta_2018 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_beta\user_beta_2018.csv")
beta_2019 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_beta\user_beta_2019.csv")
beta_2020 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_beta\user_beta_2020.csv")
beta_2021 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_beta\user_beta_2021.csv")
beta_2022 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_beta\user_beta_2022.csv")

# %%
delta_2016 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_delta\user_delta_2016.csv")
delta_2017 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_delta\user_delta_2017.csv")
delta_2018 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_delta\user_delta_2018.csv")
delta_2019 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_delta\user_delta_2019.csv")
delta_2020 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_delta\user_delta_2020.csv")
delta_2021 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_delta\user_delta_2021.csv")
delta_2022 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_delta\user_delta_2022.csv")

# %%
epsilon_2016 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_epsilon\user_epsilon_2016.csv")
epsilon_2017 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_epsilon\user_epsilon_2017.csv")
epsilon_2018 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_epsilon\user_epsilon_2018.csv")
epsilon_2019 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_epsilon\user_epsilon_2019.csv")
epsilon_2020 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_epsilon\user_epsilon_2020.csv")
epsilon_2021 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_epsilon\user_epsilon_2021.csv")
epsilon_2022 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_epsilon\user_epsilon_2022.csv")

# %%
gamma_2016 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_gamma\user_gamma_2016.csv")
gamma_2017 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_gamma\user_gamma_2017.csv")
gamma_2018 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_gamma\user_gamma_2018.csv")
gamma_2019 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_gamma\user_gamma_2019.csv")
gamma_2020 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_gamma\user_gamma_2020.csv")
gamma_2021 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_gamma\user_gamma_2021.csv")
gamma_2022 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_gamma\user_gamma_2022.csv")

# %%
zeta_2020 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_zeta\user_zeta_2020.csv")
zeta_2021 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_zeta\user_zeta_2021.csv")
zeta_2022 = pd.read_csv(r"F:\Kedge\data\recovered_data\user_zeta\user_zeta_2022.csv")

# %%
zeta_2020.info()
zeta_2021.info()
zeta_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   album             100 non-null    object
#  2   artist            100 non-null    object
#  3   release_date      100 non-null    object
#  4   length            100 non-null    int64
#  5   popularity        100 non-null    int64
#  6   acousticness      100 non-null    float64
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  loudness          100 non-null    float64
#  12  speechiness       100 non-null    float64
#  13  tempo             100 non-null    float64
#  14  valence           100 non-null    float64
#  15  time_signature    100 non-null    int64
# ...

# %%
gamma_2016.info()
gamma_2017.info()
gamma_2018.info()
gamma_2019.info()
gamma_2020.info()
gamma_2021.info()
gamma_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   album             100 non-null    object
#  2   artist            100 non-null    object
#  3   release_date      100 non-null    object
#  4   length            100 non-null    int64
#  5   popularity        100 non-null    int64
#  6   acousticness      100 non-null    float64
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  loudness          100 non-null    float64
#  12  speechiness       100 non-null    float64
#  13  tempo             100 non-null    float64
#  14  valence           100 non-null    float64
#  15  time_signature    100 non-null    int64
# ...

# %%
epsilon_2016.info()
epsilon_2017.info()
epsilon_2018.info()
epsilon_2019.info()
epsilon_2020.info()
epsilon_2021.info()
epsilon_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   album             100 non-null    object
#  2   artist            100 non-null    object
#  3   release_date      100 non-null    object
#  4   length            100 non-null    int64
#  5   popularity        100 non-null    int64
#  6   acousticness      100 non-null    float64
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  loudness          100 non-null    float64
#  12  speechiness       100 non-null    float64
#  13  tempo             100 non-null    float64
#  14  valence           100 non-null    float64
#  15  time_signature    100 non-null    int64
# ...

# %%
delta_2016.info()
delta_2017.info()
delta_2018.info()
delta_2019.info()
delta_2020.info()
delta_2021.info()
delta_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   album             100 non-null    object
#  2   artist            100 non-null    object
#  3   release_date      100 non-null    object
#  4   length            100 non-null    int64
#  5   popularity        100 non-null    int64
#  6   acousticness      100 non-null    float64
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  loudness          100 non-null    float64
#  12  speechiness       100 non-null    float64
#  13  tempo             100 non-null    float64
#  14  valence           100 non-null    float64
#  15  time_signature    100 non-null    int64
# ...

# %%
beta_2016.info()
beta_2017.info()
beta_2018.info()
beta_2019.info()
beta_2020.info()
beta_2021.info()
beta_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   album             100 non-null    object
#  2   artist            100 non-null    object
#  3   release_date      100 non-null    object
#  4   length            100 non-null    int64
#  5   popularity        100 non-null    int64
#  6   acousticness      100 non-null    float64
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  loudness          100 non-null    float64
#  12  speechiness       100 non-null    float64
#  13  tempo             100 non-null    float64
#  14  valence           100 non-null    float64
#  15  time_signature    100 non-null    int64
# ...

# %%
alpha_2016.info()
alpha_2017.info()
alpha_2018.info()
alpha_2019.info()
alpha_2020.info()
alpha_2021.info()
alpha_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   album             100 non-null    object
#  2   artist            100 non-null    object
#  3   release_date      100 non-null    object
#  4   length            100 non-null    int64
#  5   popularity        100 non-null    int64
#  6   acousticness      100 non-null    float64
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  loudness          100 non-null    float64
#  12  speechiness       100 non-null    float64
#  13  tempo             100 non-null    float64
#  14  valence           100 non-null    float64
#  15  time_signature    100 non-null    int64
# ...

# %%
alpha_df = pd.concat([alpha_2016, alpha_2017, alpha_2018, alpha_2019, alpha_2020,alpha_2021, alpha_2022], ignore_index=True,axis=0)
beta_df = pd.concat([beta_2016, beta_2017, beta_2018, beta_2019, beta_2020, beta_2021, beta_2022], ignore_index=True, axis=0)
delta_df = pd.concat([delta_2016, delta_2017, delta_2018, delta_2019, delta_2020, delta_2021, delta_2022], ignore_index=True, axis=0)
epsilon_df = pd.concat([epsilon_2016, epsilon_2017, epsilon_2018, epsilon_2019, epsilon_2020, epsilon_2021, epsilon_2022], ignore_index=True, axis=0)
gamma_df = pd.concat([gamma_2016, gamma_2017, gamma_2018, gamma_2019, gamma_2020, gamma_2021, gamma_2022], ignore_index=True, axis=0)
zeta_df = pd.concat([zeta_2020, zeta_2021, zeta_2022], ignore_index=True, axis=0)

# %%
mixed_playlist = pd.concat([alpha_df, beta_df, delta_df, epsilon_df, gamma_df, zeta_df], ignore_index=True, axis=0)

# %%
mixed_playlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3799 entries, 0 to 3798
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              3790 non-null   object
#  1   album             3790 non-null   object
#  2   artist            3799 non-null   object
#  3   release_date      3799 non-null   object
#  4   length            3799 non-null   int64
#  5   popularity        3799 non-null   int64
#  6   acousticness      3799 non-null   float64
#  7   danceability      3799 non-null   float64
#  8   energy            3799 non-null   float64
#  9   instrumentalness  3799 non-null   float64
#  10  liveness          3799 non-null   float64
#  11  loudness          3799 non-null   float64
#  12  speechiness       3799 non-null   float64
#  13  tempo             3799 non-null   float64
#  14  valence           3799 non-null   float64
#  15  time_signature    3799 non-null   int64
# ...

# %%
mixed_playlist.head()
# Out:
#                      name                    album              artist  \
# 0          Petit bonhomme  Tant Pis ! Tant Mieux !        Les Wriggles
# 1  Bei Mir Bist Du Schoen         Wake Up In Paris    The Hot Sardines
# 2    Les gens qui doutent          Favourite Songs      Vincent Delerm
# 3             Les saintes           Jusqu'à la mer  Amélie-Les-Crayons
# 4  Les moutons - Cuvée 97                Antaology            Matmatah
#
#   release_date  length  popularity  acousticness  danceability  energy  \
# 0   2007-11-19  203746           1         0.863         0.827   0.190
# 1   2014-10-20  246440          18         0.613         0.725   0.454
# 2   2007-10-29  216400           0         0.922         0.383   0.526
# 3   2012-10-08  141000          21         0.897         0.858   0.392
# 4   2015-09-25  229560          16         0.500         0.607   0.951
#
#    instrumentalness  ...  speechiness    tempo  valence  time_signature  key  \
# ...

# %%
mixed_playlist.drop_duplicates(subset=['user','name'])
# Out:
#                         name                    album              artist  \
# 0             Petit bonhomme  Tant Pis ! Tant Mieux !        Les Wriggles
# 1     Bei Mir Bist Du Schoen         Wake Up In Paris    The Hot Sardines
# 2       Les gens qui doutent          Favourite Songs      Vincent Delerm
# 3                Les saintes           Jusqu'à la mer  Amélie-Les-Crayons
# 4     Les moutons - Cuvée 97                Antaology            Matmatah
# ...                      ...                      ...                 ...
# 3794         The Masked Ball                Boundless   Pomegranate Tiger
# 3795                Le milli                 ZZCCMXTP          KronoMuzik
# 3796             Salma Hayek              Salma Hayek        WARGASM (UK)
# 3797               Lezgongue                 ZZCCMXTP          KronoMuzik
# 3798        The Water's Fine     The Stuff of Legends     Challenger Deep
#
#      release_date  length  popularity  acousticness  danceability  energy  \
# ...

# %%
mixed_playlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3799 entries, 0 to 3798
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              3790 non-null   object
#  1   album             3790 non-null   object
#  2   artist            3799 non-null   object
#  3   release_date      3799 non-null   object
#  4   length            3799 non-null   int64
#  5   popularity        3799 non-null   int64
#  6   acousticness      3799 non-null   float64
#  7   danceability      3799 non-null   float64
#  8   energy            3799 non-null   float64
#  9   instrumentalness  3799 non-null   float64
#  10  liveness          3799 non-null   float64
#  11  loudness          3799 non-null   float64
#  12  speechiness       3799 non-null   float64
#  13  tempo             3799 non-null   float64
#  14  valence           3799 non-null   float64
#  15  time_signature    3799 non-null   int64
# ...

# %%
le = LabelEncoder()

# %%
mixed_playlist[['artist']].value_counts()
# Out:
# artist
# Various Artists    124
# Gaël Faye           71
# Leonard Cohen       49
# Sofiane Pamart      39
# Sexion d'Assaut     36
#                   ...
# Danheim              1
# Limousine            1
# Lior Shoov           1
# Liquid Cinema        1
# Bonga                1
# Name: count, Length: 1393, dtype: int64

# %%
mixed_playlist[['user']].value_counts()
# Out:
# user
# alpha      700
# beta       700
# delta      700
# gamma      700
# epsilon    699
# zeta       300
# Name: count, dtype: int64

# %%
mixed_playlist['user'] = le.fit_transform(mixed_playlist['user'])

# %%
mixed_playlist['artist'] = le.fit_transform(mixed_playlist['artist'])

# %%
X = mixed_playlist[['artist','length','popularity','energy','instrumentalness','liveness','loudness','speechiness','valence']]
y = mixed_playlist['user']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,classification_report,roc_curve,auc,roc_auc_score 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, RepeatedStratifiedKFold

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,shuffle=True,random_state=42)

# %%
rf = RandomForestClassifier(random_state=42)

# %%
dt=DecisionTreeClassifier(random_state=42)

# %%
space = dict()

space['criterion'] = ['gini', 'entropy']
space['n_estimators'] = [1,10,100,300]
space['max_depth'] = [1,5,15,20,25,30]
space['max_features'] = ['sqrt', 'log2']
search = GridSearchCV(rf, space, scoring='accuracy')

# execute search
result = search.fit(X=X_train, y=y_train)
# summarize result
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# Best Score: 0.5565870891919064
# Best Hyperparameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 300}
